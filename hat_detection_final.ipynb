# %%
# %pip install ultralytics roboflow opencv-python chardet
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.1  Python-3.10.14 torch-2.2.2+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# Setup complete  (16 CPUs, 15.4 GB RAM, 295.3/952.3 GB disk)

# %%
pip install --user opencv-python
# Out:
# ...
#
# ...

# %%
pip install -U --force-reinstall charset-normalizer
# Out:
# ...
#   Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl.metadata (34 kB)
# Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl (100 kB)
# ...
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.3.2
#     Uninstalling charset-normalizer-3.3.2:
#       Successfully uninstalled charset-normalizer-3.3.2
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\gayat\anaconda3\envs\py310\Lib\site-packages\~harset_normalizer'.
#   You can safely remove it manually.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="jQPxpWainPsgLs7DI8TI")
project = rf.workspace("advance-ml-hat-detection").project("hat-detection-00afz")
version = project.version(1)
dataset = version.download("yolov8-obb")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Hat-Detection-1 in yolov8-obb:: 100%|██████████| 98/98 [00:00<00:00, 966.99it/s]

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=Hat-Detection-1/data.yaml epochs=20 imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.2.1 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.0 🚀 Python-3.10.14 torch-2.2.2 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 8188MiB)
# ...

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=Hat-Detection-1/data.yaml
# Out:
# Ultralytics YOLOv8.2.0 🚀 Python-3.10.14 torch-2.2.2 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 8188MiB)
# /home/rio/anaconda3/envs/pn310/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1711403388920/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /mnt/d/New folder/Hat-Detection-1/valid/labels.cache... 8 images,
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all          8          8      0.333      0.917      0.567      0.258
#                    Hat          8          6      0.663      0.833      0.883      0.366
#                 No Hat          8          2    0.00345          1       0.25      0.149
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.5 source=Hat-Detection-1/test/images
# Out:
# Ultralytics YOLOv8.2.1 🚀 Python-3.10.14 torch-2.2.2+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/5 c:\Users\gayat\Downloads\New folder\Hat-Detection-1\test\images\0de39c22-faf3-11ee-aba0-14133358215e_jpg.rf.1b42da9cbf450fb45b09be9fc6bca29a.jpg: 640x640 (no detections), 506.7ms
# image 2/5 c:\Users\gayat\Downloads\New folder\Hat-Detection-1\test\images\0f6bc3c0-faf3-11ee-94f6-14133358215e_jpg.rf.a2498ee98aff5ed785c106533715a127.jpg: 640x640 (no detections), 518.2ms
# image 3/5 c:\Users\gayat\Downloads\New folder\Hat-Detection-1\test\images\ce303c0e-faf2-11ee-91a8-14133358215e_jpg.rf.4f46f43dc6c328e3057edb3099df0b8d.jpg: 640x640 (no detections), 450.3ms
# image 4/5 c:\Users\gayat\Downloads\New folder\Hat-Detection-1\test\images\d4c6c6e4-faf2-11ee-b8eb-14133358215e_jpg.rf.e8ab74eb1b09dcf478e341a82dcd9e6c.jpg: 640x640 (no detections), 452.5ms
# ...

# %%
from ultralytics import YOLO
#from ultralytics.yolo.v8.detect.predict import DetectionPredictor
import cv2
model = YOLO("runs/detect/train3/weights/best.pt")
results = model.predict(source= "0", show=True,conf=0.86) # accepts all formats
print(results)
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 (no detections), 505.7ms
# 0: 480x640 (no detections), 667.2ms
# 0: 480x640 (no detections), 427.7ms
# 0: 480x640 1 No Hat, 405.0ms
# 0: 480x640 2 No Hats, 415.2ms
# 0: 480x640 1 No Hat, 398.6ms
# 0: 480x640 1 No Hat, 408.7ms
# 0: 480x640 2 No Hats, 418.9ms
# 0: 480x640 1 No Hat, 397.6ms
# 0: 480x640 1 No Hat, 390.9ms
# 0: 480x640 1 No Hat, 386.9ms
# ...
